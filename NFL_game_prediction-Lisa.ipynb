# %%
from sportsreference.nfl.boxscore import Boxscores, Boxscore
import pandas as pd
import numpy as np

# %%
def game_data(game_df,game_stats):
    try:
        away_team_df = game_df[['away_name', 'away_abbr', 'away_score']].rename(columns = {'away_name': 'team_name', 'away_abbr': 'team_abbr', 'away_score': 'score'})
        home_team_df = game_df[['home_name','home_abbr', 'home_score']].rename(columns = {'home_name': 'team_name', 'home_abbr': 'team_abbr', 'home_score': 'score'})
        try:
            if game_df.loc[0,'away_score'] > game_df.loc[0,'home_score']:
                away_team_df = pd.merge(away_team_df, pd.DataFrame({'game_won' : [1], 'game_lost' : [0]}),left_index = True, right_index = True)
                home_team_df = pd.merge(home_team_df, pd.DataFrame({'game_won' : [0], 'game_lost' : [1]}),left_index = True, right_index = True)
            elif game_df.loc[0,'away_score'] < game_df.loc[0,'home_score']:
                away_team_df = pd.merge(away_team_df, pd.DataFrame({'game_won' : [0], 'game_lost' : [1]}),left_index = True, right_index = True)
                home_team_df = pd.merge(home_team_df, pd.DataFrame({'game_won' : [1], 'game_lost' : [0]}),left_index = True, right_index = True)
            else: 
                away_team_df = pd.merge(away_team_df, pd.DataFrame({'game_won' : [0], 'game_lost' : [0]}),left_index = True, right_index = True)
                home_team_df = pd.merge(home_team_df, pd.DataFrame({'game_won' : [0], 'game_lost' : [0]}),left_index = True, right_index = True)
        except TypeError:
                away_team_df = pd.merge(away_team_df, pd.DataFrame({'game_won' : [np.nan], 'game_lost' : [np.nan]}),left_index = True, right_index = True)
                home_team_df = pd.merge(home_team_df, pd.DataFrame({'game_won' : [np.nan], 'game_lost' : [np.nan]}),left_index = True, right_index = True)        

        away_stats_df = game_stats.dataframe[['away_first_downs', 'away_fourth_down_attempts',
               'away_fourth_down_conversions', 'away_fumbles', 'away_fumbles_lost',
               'away_interceptions', 'away_net_pass_yards', 'away_pass_attempts',
               'away_pass_completions', 'away_pass_touchdowns', 'away_pass_yards',
               'away_penalties', 'away_points', 'away_rush_attempts',
               'away_rush_touchdowns', 'away_rush_yards', 'away_third_down_attempts',
               'away_third_down_conversions', 'away_time_of_possession',
               'away_times_sacked', 'away_total_yards', 'away_turnovers',
               'away_yards_from_penalties', 'away_yards_lost_from_sacks']].reset_index().drop(columns ='index').rename(columns = {
               'away_first_downs': 'first_downs', 'away_fourth_down_attempts':'fourth_down_attempts',
               'away_fourth_down_conversions':'fourth_down_conversions' , 'away_fumbles': 'fumbles', 'away_fumbles_lost': 'fumbles_lost',
               'away_interceptions': 'interceptions', 'away_net_pass_yards':'net_pass_yards' , 'away_pass_attempts': 'pass_attempts',
               'away_pass_completions':'pass_completions' , 'away_pass_touchdowns': 'pass_touchdowns', 'away_pass_yards': 'pass_yards',
               'away_penalties': 'penalties', 'away_points': 'points', 'away_rush_attempts': 'rush_attempts',
               'away_rush_touchdowns': 'rush_touchdowns', 'away_rush_yards': 'rush_yards', 'away_third_down_attempts': 'third_down_attempts',
               'away_third_down_conversions': 'third_down_conversions', 'away_time_of_possession': 'time_of_possession',
               'away_times_sacked': 'times_sacked', 'away_total_yards': 'total_yards', 'away_turnovers': 'turnovers',
               'away_yards_from_penalties':'yards_from_penalties', 'away_yards_lost_from_sacks': 'yards_lost_from_sacks'})

        home_stats_df = game_stats.dataframe[['home_first_downs', 'home_fourth_down_attempts',
               'home_fourth_down_conversions', 'home_fumbles', 'home_fumbles_lost',
               'home_interceptions', 'home_net_pass_yards', 'home_pass_attempts',
               'home_pass_completions', 'home_pass_touchdowns', 'home_pass_yards',
               'home_penalties', 'home_points', 'home_rush_attempts',
               'home_rush_touchdowns', 'home_rush_yards', 'home_third_down_attempts',
               'home_third_down_conversions', 'home_time_of_possession',
               'home_times_sacked', 'home_total_yards', 'home_turnovers',
               'home_yards_from_penalties', 'home_yards_lost_from_sacks']].reset_index().drop(columns = 'index').rename(columns = {
               'home_first_downs': 'first_downs', 'home_fourth_down_attempts':'fourth_down_attempts',
               'home_fourth_down_conversions':'fourth_down_conversions' , 'home_fumbles': 'fumbles', 'home_fumbles_lost': 'fumbles_lost',
               'home_interceptions': 'interceptions', 'home_net_pass_yards':'net_pass_yards' , 'home_pass_attempts': 'pass_attempts',
               'home_pass_completions':'pass_completions' , 'home_pass_touchdowns': 'pass_touchdowns', 'home_pass_yards': 'pass_yards',
               'home_penalties': 'penalties', 'home_points': 'points', 'home_rush_attempts': 'rush_attempts',
               'home_rush_touchdowns': 'rush_touchdowns', 'home_rush_yards': 'rush_yards', 'home_third_down_attempts': 'third_down_attempts',
               'home_third_down_conversions': 'third_down_conversions', 'home_time_of_possession': 'time_of_possession',
               'home_times_sacked': 'times_sacked', 'home_total_yards': 'total_yards', 'home_turnovers': 'turnovers',
               'home_yards_from_penalties':'yards_from_penalties', 'home_yards_lost_from_sacks': 'yards_lost_from_sacks'})

        away_team_df = pd.merge(away_team_df, away_stats_df,left_index = True, right_index = True)
        home_team_df = pd.merge(home_team_df, home_stats_df,left_index = True, right_index = True)
        try:
            away_team_df['time_of_possession'] = (int(away_team_df['time_of_possession'].loc[0][0:2]) * 60) + int(away_team_df['time_of_possession'].loc[0][3:5])
            home_team_df['time_of_possession'] = (int(home_team_df['time_of_possession'].loc[0][0:2]) * 60) + int(home_team_df['time_of_possession'].loc[0][3:5])
        except TypeError:
            away_team_df['time_of_possession'] = np.nan
            home_team_df['time_of_possession'] = np.nan
    except TypeError:
        away_team_df = pd.DataFrame()
        home_team_df = pd.DataFrame()
    return away_team_df, home_team_df


def game_data_up_to_week(weeks,year):
    weeks_games_df = pd.DataFrame()
    for w in range(len(weeks)):
        date_string = str(weeks[w]) + '-' + str(year)
        week_scores = Boxscores(weeks[w],year)
        week_games_df = pd.DataFrame()
        for g in range(len(week_scores.games[date_string])):
            game_str = week_scores.games[date_string][g]['boxscore']
            game_stats = Boxscore(game_str)
            game_df = pd.DataFrame(week_scores.games[date_string][g], index = [0])
            away_team_df, home_team_df = game_data(game_df,game_stats)
            away_team_df['week'] = weeks[w]
            home_team_df['week'] = weeks[w]
            week_games_df = pd.concat([week_games_df,away_team_df])
            week_games_df = pd.concat([week_games_df,home_team_df])
        weeks_games_df = pd.concat([weeks_games_df,week_games_df])
    return weeks_games_df

def get_schedule(year):
    weeks = list(range(1,18))
    schedule_df = pd.DataFrame()
    for w in range(len(weeks)):
        date_string = str(weeks[w]) + '-' + str(year)
        week_scores = Boxscores(weeks[w],year)
        week_games_df = pd.DataFrame()
        for g in range(len(week_scores.games[date_string])):
            game = pd.DataFrame(week_scores.games[date_string][g], index = [0])[['away_name', 'away_abbr','home_name', 'home_abbr','winning_name', 'winning_abbr' ]]
            game['week'] = weeks[w]
            week_games_df = pd.concat([week_games_df,game])
        schedule_df = pd.concat([schedule_df, week_games_df]).reset_index().drop(columns = 'index') 
    return schedule_df 

def agg_weekly_data(schedule_df,weeks_games_df,current_week,weeks):
    schedule_df = schedule_df[schedule_df.week < current_week]
    agg_games_df = pd.DataFrame()
    for w in range(1,len(weeks)):
        games_df = schedule_df[schedule_df.week == weeks[w]]
        agg_weekly_df = weeks_games_df[weeks_games_df.week < weeks[w]].drop(columns = ['score','week','game_won', 'game_lost']).groupby(by=["team_name", "team_abbr"]).mean().reset_index()
        win_loss_df = weeks_games_df[weeks_games_df.week < weeks[w]][["team_name", "team_abbr",'game_won', 'game_lost']].groupby(by=["team_name", "team_abbr"]).sum().reset_index()
        win_loss_df['win_perc'] = win_loss_df['game_won'] / (win_loss_df['game_won'] + win_loss_df['game_lost'])
        win_loss_df = win_loss_df.drop(columns = ['game_won', 'game_lost'])

        try:
            agg_weekly_df['fourth_down_perc'] = agg_weekly_df['fourth_down_conversions'] / agg_weekly_df['fourth_down_attempts']  
        except ZeroDivisionError:
            agg_weekly_df['fourth_down_perc'] = 0 
        agg_weekly_df['fourth_down_perc'] = agg_weekly_df['fourth_down_perc'].fillna(0)

        try:
            agg_weekly_df['third_down_perc'] = agg_weekly_df['third_down_conversions'] / agg_weekly_df['third_down_attempts']  
        except ZeroDivisionError:
            agg_weekly_df['third_down_perc'] = 0
        agg_weekly_df['third_down_perc'] = agg_weekly_df['third_down_perc'].fillna(0)  

        agg_weekly_df = agg_weekly_df.drop(columns = ['fourth_down_attempts', 'fourth_down_conversions', 'third_down_attempts', 'third_down_conversions'])
        agg_weekly_df = pd.merge(win_loss_df,agg_weekly_df,left_on = ['team_name', 'team_abbr'], right_on = ['team_name', 'team_abbr'])

        away_df = pd.merge(games_df,agg_weekly_df,how = 'inner', left_on = ['away_name', 'away_abbr'], right_on = ['team_name', 'team_abbr']).drop(columns = ['team_name', 'team_abbr']).rename(columns = {
                'win_perc': 'away_win_perc',
               'first_downs': 'away_first_downs', 'fumbles': 'away_fumbles', 'fumbles_lost':'away_fumbles_lost', 'interceptions':'away_interceptions',
               'net_pass_yards': 'away_net_pass_yards', 'pass_attempts':'away_pass_attempts', 'pass_completions':'away_pass_completions',
               'pass_touchdowns':'away_pass_touchdowns', 'pass_yards':'away_pass_yards', 'penalties':'away_penalties', 'points':'away_points', 'rush_attempts':'away_rush_attempts',
               'rush_touchdowns':'away_rush_touchdowns', 'rush_yards':'away_rush_yards', 'time_of_possession':'away_time_of_possession', 'times_sacked':'away_times_sacked',
               'total_yards':'away_total_yards', 'turnovers':'away_turnovers', 'yards_from_penalties':'away_yards_from_penalties',
               'yards_lost_from_sacks': 'away_yards_lost_from_sacks', 'fourth_down_perc':'away_fourth_down_perc', 'third_down_perc':'away_third_down_perc'})

        home_df = pd.merge(games_df,agg_weekly_df,how = 'inner', left_on = ['home_name', 'home_abbr'], right_on = ['team_name', 'team_abbr']).drop(columns = ['team_name', 'team_abbr']).rename(columns = {
                'win_perc': 'home_win_perc',
               'first_downs': 'home_first_downs', 'fumbles': 'home_fumbles', 'fumbles_lost':'home_fumbles_lost', 'interceptions':'home_interceptions',
               'net_pass_yards': 'home_net_pass_yards', 'pass_attempts':'home_pass_attempts', 'pass_completions':'home_pass_completions',
               'pass_touchdowns':'home_pass_touchdowns', 'pass_yards':'home_pass_yards', 'penalties':'home_penalties', 'points':'home_points', 'rush_attempts':'home_rush_attempts',
               'rush_touchdowns':'home_rush_touchdowns', 'rush_yards':'home_rush_yards', 'time_of_possession':'home_time_of_possession', 'times_sacked':'home_times_sacked',
               'total_yards':'home_total_yards', 'turnovers':'home_turnovers', 'yards_from_penalties':'home_yards_from_penalties',
               'yards_lost_from_sacks': 'home_yards_lost_from_sacks', 'fourth_down_perc':'home_fourth_down_perc', 'third_down_perc':'home_third_down_perc'})

        agg_weekly_df = pd.merge(away_df,home_df,left_on = ['away_name', 'away_abbr', 'home_name', 'home_abbr', 'winning_name',
               'winning_abbr', 'week'], right_on = ['away_name', 'away_abbr', 'home_name', 'home_abbr', 'winning_name',
               'winning_abbr', 'week'])

        agg_weekly_df['win_perc_dif'] = agg_weekly_df['away_win_perc'] - agg_weekly_df['home_win_perc']
        agg_weekly_df['first_downs_dif'] = agg_weekly_df['away_first_downs'] - agg_weekly_df['home_first_downs']
        agg_weekly_df['fumbles_dif'] = agg_weekly_df['away_fumbles'] - agg_weekly_df['home_fumbles']
        agg_weekly_df['interceptions_dif'] = agg_weekly_df['away_interceptions'] - agg_weekly_df['home_interceptions']
        agg_weekly_df['net_pass_yards_dif'] = agg_weekly_df['away_net_pass_yards'] - agg_weekly_df['home_net_pass_yards']
        agg_weekly_df['pass_attempts_dif'] = agg_weekly_df['away_pass_attempts'] - agg_weekly_df['home_pass_attempts']
        agg_weekly_df['pass_completions_dif'] = agg_weekly_df['away_pass_completions'] - agg_weekly_df['home_pass_completions']
        agg_weekly_df['pass_touchdowns_dif'] = agg_weekly_df['away_pass_touchdowns'] - agg_weekly_df['home_pass_touchdowns']
        agg_weekly_df['pass_yards_dif'] = agg_weekly_df['away_pass_yards'] - agg_weekly_df['home_pass_yards']
        agg_weekly_df['penalties_dif'] = agg_weekly_df['away_penalties'] - agg_weekly_df['home_penalties']
        agg_weekly_df['points_dif'] = agg_weekly_df['away_points'] - agg_weekly_df['home_points']
        agg_weekly_df['rush_attempts_dif'] = agg_weekly_df['away_rush_attempts'] - agg_weekly_df['home_rush_attempts']
        agg_weekly_df['rush_touchdowns_dif'] = agg_weekly_df['away_rush_touchdowns'] - agg_weekly_df['home_rush_touchdowns']
        agg_weekly_df['rush_yards_dif'] = agg_weekly_df['away_rush_yards'] - agg_weekly_df['home_rush_yards']
        agg_weekly_df['time_of_possession_dif'] = agg_weekly_df['away_time_of_possession'] - agg_weekly_df['home_time_of_possession']
        agg_weekly_df['times_sacked_dif'] = agg_weekly_df['away_times_sacked'] - agg_weekly_df['home_times_sacked']
        agg_weekly_df['total_yards_dif'] = agg_weekly_df['away_total_yards'] - agg_weekly_df['home_total_yards']
        agg_weekly_df['turnovers_dif'] = agg_weekly_df['away_turnovers'] - agg_weekly_df['home_turnovers']
        agg_weekly_df['yards_from_penalties_dif'] = agg_weekly_df['away_yards_from_penalties'] - agg_weekly_df['home_yards_from_penalties']
        agg_weekly_df['yards_lost_from_sacks_dif'] = agg_weekly_df['away_yards_lost_from_sacks'] - agg_weekly_df['home_yards_lost_from_sacks']
        agg_weekly_df['fourth_down_perc_dif'] = agg_weekly_df['away_fourth_down_perc'] - agg_weekly_df['home_fourth_down_perc']
        agg_weekly_df['third_down_perc_dif'] = agg_weekly_df['away_third_down_perc'] - agg_weekly_df['home_third_down_perc']

        agg_weekly_df = agg_weekly_df.drop(columns = ['away_win_perc',
               'away_first_downs', 'away_fumbles', 'away_fumbles_lost', 'away_interceptions',
               'away_net_pass_yards', 'away_pass_attempts','away_pass_completions',
               'away_pass_touchdowns', 'away_pass_yards', 'away_penalties', 'away_points', 'away_rush_attempts',
               'away_rush_touchdowns', 'away_rush_yards', 'away_time_of_possession', 'away_times_sacked',
               'away_total_yards', 'away_turnovers', 'away_yards_from_penalties',
               'away_yards_lost_from_sacks','away_fourth_down_perc', 'away_third_down_perc','home_win_perc',
               'home_first_downs', 'home_fumbles', 'home_fumbles_lost', 'home_interceptions',
               'home_net_pass_yards', 'home_pass_attempts','home_pass_completions',
               'home_pass_touchdowns', 'home_pass_yards', 'home_penalties', 'home_points', 'home_rush_attempts',
               'home_rush_touchdowns', 'home_rush_yards', 'home_time_of_possession', 'home_times_sacked',
               'home_total_yards', 'home_turnovers', 'home_yards_from_penalties',
               'home_yards_lost_from_sacks','home_fourth_down_perc', 'home_third_down_perc'])
        
        if (agg_weekly_df['winning_name'].isnull().values.any() and weeks[w] > 3):
            agg_weekly_df['result'] = np.nan
            print(f"Week {weeks[w]} games have not finished yet.")
        else:
            agg_weekly_df['result'] = agg_weekly_df['winning_name'] == agg_weekly_df['away_name']
            agg_weekly_df['result'] = agg_weekly_df['result'].astype('float')
        agg_weekly_df = agg_weekly_df.drop(columns = ['winning_name', 'winning_abbr'])
        agg_games_df = pd.concat([agg_games_df, agg_weekly_df])
    agg_games_df = agg_games_df.reset_index().drop(columns = 'index')
    agg_games_df = agg_games_df.drop(index = 20, axis=0)
    return agg_games_df

def get_elo():
    elo_df = pd.read_csv('nfl_elo_latest.csv')
    elo_df = elo_df.drop(columns = ['season','neutral' ,'playoff', 'elo_prob1', 'elo_prob2', 'elo1_post', 'elo2_post',
           'qbelo1_pre', 'qbelo2_pre', 'qb1', 'qb2', 'qb1_adj', 'qb2_adj', 'qbelo_prob1', 'qbelo_prob2',
           'qb1_game_value', 'qb2_game_value', 'qb1_value_post', 'qb2_value_post',
           'qbelo1_post', 'qbelo2_post', 'score1', 'score2'])
    elo_df.date = pd.to_datetime(elo_df.date)
    elo_df = elo_df[elo_df.date < '01-05-2021']

    elo_df['team1'] = elo_df['team1'].replace(['KC', 'JAX', 'CAR', 'BAL', 'BUF', 'MIN', 'DET', 'ATL', 'NE', 'WSH',
           'CIN', 'NO', 'SF', 'LAR', 'NYG', 'DEN', 'CLE', 'IND', 'TEN', 'NYJ',
           'TB', 'MIA', 'PIT', 'PHI', 'GB', 'CHI', 'DAL', 'ARI', 'LAC', 'HOU',
           'SEA', 'OAK'],
            ['kan','jax','car', 'rav', 'buf', 'min', 'det', 'atl', 'nwe', 'was', 
            'cin', 'nor', 'sfo', 'ram', 'nyg', 'den', 'cle', 'clt', 'oti', 'nyj', 
             'tam','mia', 'pit', 'phi', 'gnb', 'chi', 'dal', 'crd', 'sdg', 'htx', 'sea', 'rai' ])
    elo_df['team2'] = elo_df['team2'].replace(['KC', 'JAX', 'CAR', 'BAL', 'BUF', 'MIN', 'DET', 'ATL', 'NE', 'WSH',
           'CIN', 'NO', 'SF', 'LAR', 'NYG', 'DEN', 'CLE', 'IND', 'TEN', 'NYJ',
           'TB', 'MIA', 'PIT', 'PHI', 'GB', 'CHI', 'DAL', 'ARI', 'LAC', 'HOU',
           'SEA', 'OAK'],
            ['kan','jax','car', 'rav', 'buf', 'min', 'det', 'atl', 'nwe', 'was', 
            'cin', 'nor', 'sfo', 'ram', 'nyg', 'den', 'cle', 'clt', 'oti', 'nyj', 
             'tam','mia', 'pit', 'phi', 'gnb', 'chi', 'dal', 'crd', 'sdg', 'htx', 'sea', 'rai' ])
    return elo_df

def merge_rankings(agg_games_df,elo_df):
    agg_games_df = pd.merge(agg_games_df, elo_df, how = 'inner', left_on = ['home_abbr', 'away_abbr'], right_on = ['team1', 'team2']).drop(columns = ['date','team1', 'team2'])
    agg_games_df['elo_dif'] = agg_games_df['elo2_pre'] - agg_games_df['elo1_pre']
    agg_games_df['qb_dif'] = agg_games_df['qb2_value_pre'] - agg_games_df['qb1_value_pre']
    agg_games_df = agg_games_df.drop(columns = ['elo1_pre', 'elo2_pre', 'qb1_value_pre', 'qb2_value_pre'])
    return agg_games_df

# def prep_test_train(current_week,weeks,year):
#     current_week = current_week + 1
#     schedule_df  = get_schedule(year)
#     weeks_games_df = game_data_up_to_week(weeks,year)
#     agg_games_df = agg_weekly_data(schedule_df,weeks_games_df,current_week,weeks)
#     elo_df = get_elo()
#     agg_games_df = merge_rankings(agg_games_df, elo_df)
#     train_df = agg_games_df[agg_games_df.result.notna()]
#     current_week = current_week - 1
#     test_df = agg_games_df[agg_games_df.week == current_week]
#     return test_df, train_df

def prep_test_train(current_week,weeks,year):
    current_week = current_week + 1
    schedule_df  = get_schedule(year)
    weeks_games_df = game_data_up_to_week(weeks,year)
    agg_games_df = agg_weekly_data(schedule_df,weeks_games_df,current_week,weeks)
    #elo_df = get_elo()
    #agg_games_df = merge_rankings(agg_games_df, elo_df)
    train_df = agg_games_df[agg_games_df.result.notna()]
    current_week = current_week - 1
    test_df = agg_games_df[agg_games_df.week == current_week]
    return test_df, train_df

def display(y_pred,X_test):
    for g in range(len(y_pred)):
        win_prob = round(y_pred[g],2)
        away_team = X_test.reset_index().drop(columns = 'index').loc[g,'away_name']
        home_team = X_test.reset_index().drop(columns = 'index').loc[g,'home_name']
        print(f'The {away_team} have a probability of {win_prob} of beating the {home_team}.')

# %%
current_week = 4
weeks = list(range(1,current_week + 1))
year = 2021

pred_games_df, comp_games_df = prep_test_train(current_week,weeks,year)

# %%
pred_games_df
# Out:
#                    away_name away_abbr             home_name home_abbr  week  \
# 32      Jacksonville Jaguars       jax    Cincinnati Bengals       cin     4
# 33            Houston Texans       htx         Buffalo Bills       buf     4
# 34  Washington Football Team       was       Atlanta Falcons       atl     4
# 35        Kansas City Chiefs       kan   Philadelphia Eagles       phi     4
# 36          Tennessee Titans       oti         New York Jets       nyj     4
# 37           New York Giants       nyg    New Orleans Saints       nor     4
# 38          Cleveland Browns       cle     Minnesota Vikings       min     4
# 39        Indianapolis Colts       clt        Miami Dolphins       mia     4
# 40         Carolina Panthers       car        Dallas Cowboys       dal     4
# 41             Detroit Lions       det         Chicago Bears       chi     4
# 42          Seattle Seahawks       sea   San Francisco 49ers       sfo     4
# 43         Arizona Cardinals       crd      Los Angeles Rams       ram     4
# 44       Pittsburgh Steelers       pit     Green Bay Packers       gnb     4
# 45          Baltimore Ravens       rav        Denver Broncos       den     4
# 46      Tampa Bay Buccaneers       tam  New England Patriots       nwe     4
# 47         Las Vegas Raiders       rai  Los Angeles Chargers       sdg     4
#
#     win_perc_dif  first_downs_dif  fumbles_dif  interceptions_dif  \
# 32     -0.666667         2.000000     1.333333           1.000000
# 33     -0.333333        -6.333333    -0.333333           0.000000
# 34      0.000000        -1.000000     0.666667           0.000000
# 35      0.000000         7.333333     0.333333           0.333333
# 36      0.666667         9.666667     1.000000          -1.333333
# 37     -0.666667         4.666667     1.333333          -0.666667
# 38      0.333333        -0.666667     0.333333           0.666667
# 39     -0.333333         4.333333    -1.000000           0.000000
# 40      0.333333        -3.000000     0.000000          -0.333333
# 41     -0.333333         8.666667    -0.333333           0.000000
# 42     -0.333333        -4.333333    -1.666667          -0.333333
# 43      0.000000         1.666667     0.000000           1.000000
# 44     -0.333333        -2.000000     0.333333           0.333333
# 45     -0.333333        -1.000000     1.333333           1.000000
# 46      0.333333         5.000000     0.333333          -0.333333
# 47      0.333333         1.333333     0.666667          -0.333333
#
#     net_pass_yards_dif  ...  rush_yards_dif  time_of_possession_dif  \
# 32           22.333333  ...       -1.333333             -299.333333
# 33          -41.333333  ...      -32.666667             -262.000000
# 34            3.000000  ...       14.333333             -280.666667
# 35           59.000000  ...      -22.333333              163.000000
# 36           53.333333  ...       79.333333              365.666667
# 37          129.000000  ...      -12.666667               -8.333333
# 38          -61.666667  ...       46.666667               54.000000
# 39           39.666667  ...       10.333333              143.000000
# 40            7.333333  ...      -33.666667              145.333333
# 41          156.666667  ...        4.666667              111.666667
# 42           37.666667  ...        2.666667             -405.333333
# 43           18.000000  ...       26.333333              294.333333
# 44           33.333333  ...      -26.666667              -24.666667
# 45          -20.666667  ...       58.333333             -282.333333
# 46          123.666667  ...      -35.333333             -198.333333
# 47           72.333333  ...        4.000000              256.000000
#
#     times_sacked_dif  total_yards_dif  turnovers_dif  \
# 32         -1.666667        21.000000       1.333333
# 33          0.666667       -74.000000      -0.333333
# 34         -1.333333        17.333333       0.333333
# 35         -0.333333        36.666667       1.333333
# 36         -1.666667       132.666667       0.000000
# 37          0.333333       116.333333       0.000000
# 38          1.333333       -15.000000       1.000000
# 39         -0.666667        50.000000      -0.333333
# 40         -0.333333       -26.333333      -0.333333
# 41         -3.000000       161.333333       0.000000
# 42          1.000000        40.333333      -1.000000
# 43          0.666667        44.333333       0.666667
# 44          0.666667         6.666667       0.000000
# 45          0.333333        37.666667       1.000000
# 46          0.000000        88.333333       0.000000
# 47          1.000000        76.333333      -0.666667
#
#     yards_from_penalties_dif  yards_lost_from_sacks_dif  fourth_down_perc_dif  \
# 32                 10.333333                 -12.666667              0.500000
# 33                  5.000000                   0.666667             -0.400000
# 34                 -0.333333                 -11.000000              0.514286
# 35                -31.333333                  -5.666667              0.000000
# 36                -23.666667                  -8.666667              0.114286
# 37                  5.333333                   1.666667             -0.166667
# 38                  6.000000                  12.000000             -0.428571
# 39                -24.000000                  -0.333333             -0.041667
# 40                 -5.666667                  -4.000000             -0.333333
# 41                  1.333333                 -23.000000              0.285714
# 42                -12.333333                   5.666667             -1.000000
# 43                 34.000000                   3.000000              0.500000
# 44                -10.000000                  -5.333333             -0.500000
# 45                 -2.333333                  -1.333333             -0.250000
# 46                 20.666667                  -7.000000             -0.166667
# 47                -12.333333                  10.000000             -0.666667
#
#     third_down_perc_dif  result
# 32            -0.060606     0.0
# 33            -0.044466     0.0
# 34            -0.068627     1.0
# 35             0.146319     1.0
# 36             0.091667     0.0
# 37             0.065015     1.0
# 38            -0.000758     1.0
# 39            -0.021868     1.0
# 40            -0.113462     0.0
# 41            -0.000795     0.0
# 42            -0.091278     1.0
# 43            -0.188018     1.0
# 44             0.051938     0.0
# 45            -0.048321     1.0
# 46            -0.030142     1.0
# 47            -0.082503     0.0
#
# [16 rows x 28 columns]

# %%
comp_games_df
# Out:
#                    away_name away_abbr                 home_name home_abbr  \
# 0            New York Giants       nyg  Washington Football Team       was
# 1         Cincinnati Bengals       cin             Chicago Bears       chi
# 2         New Orleans Saints       nor         Carolina Panthers       car
# 3          Las Vegas Raiders       rai       Pittsburgh Steelers       pit
# 4        San Francisco 49ers       sfo       Philadelphia Eagles       phi
# 5       New England Patriots       nwe             New York Jets       nyj
# 6              Buffalo Bills       buf            Miami Dolphins       mia
# 7             Denver Broncos       den      Jacksonville Jaguars       jax
# 8           Los Angeles Rams       ram        Indianapolis Colts       clt
# 9             Houston Texans       htx          Cleveland Browns       cle
# 10           Atlanta Falcons       atl      Tampa Bay Buccaneers       tam
# 11         Minnesota Vikings       min         Arizona Cardinals       crd
# 12          Tennessee Titans       oti          Seattle Seahawks       sea
# 13            Dallas Cowboys       dal      Los Angeles Chargers       sdg
# 14        Kansas City Chiefs       kan          Baltimore Ravens       rav
# 15             Detroit Lions       det         Green Bay Packers       gnb
# 16         Carolina Panthers       car            Houston Texans       htx
# 17             Chicago Bears       chi          Cleveland Browns       cle
# 18  Washington Football Team       was             Buffalo Bills       buf
# 19        Cincinnati Bengals       cin       Pittsburgh Steelers       pit
# 21           Atlanta Falcons       atl           New York Giants       nyg
# 22        New Orleans Saints       nor      New England Patriots       nwe
# 23      Los Angeles Chargers       sdg        Kansas City Chiefs       kan
# 24         Arizona Cardinals       crd      Jacksonville Jaguars       jax
# 25          Baltimore Ravens       rav             Detroit Lions       det
# 26            Miami Dolphins       mia         Las Vegas Raiders       rai
# 27             New York Jets       nyj            Denver Broncos       den
# 28      Tampa Bay Buccaneers       tam          Los Angeles Rams       ram
# 29          Seattle Seahawks       sea         Minnesota Vikings       min
# 30         Green Bay Packers       gnb       San Francisco 49ers       sfo
# 31       Philadelphia Eagles       phi            Dallas Cowboys       dal
# 32      Jacksonville Jaguars       jax        Cincinnati Bengals       cin
# 33            Houston Texans       htx             Buffalo Bills       buf
# 34  Washington Football Team       was           Atlanta Falcons       atl
# 35        Kansas City Chiefs       kan       Philadelphia Eagles       phi
# 36          Tennessee Titans       oti             New York Jets       nyj
# 37           New York Giants       nyg        New Orleans Saints       nor
# 38          Cleveland Browns       cle         Minnesota Vikings       min
# 39        Indianapolis Colts       clt            Miami Dolphins       mia
# 40         Carolina Panthers       car            Dallas Cowboys       dal
# 41             Detroit Lions       det             Chicago Bears       chi
# 42          Seattle Seahawks       sea       San Francisco 49ers       sfo
# 43         Arizona Cardinals       crd          Los Angeles Rams       ram
# 44       Pittsburgh Steelers       pit         Green Bay Packers       gnb
# 45          Baltimore Ravens       rav            Denver Broncos       den
# 46      Tampa Bay Buccaneers       tam      New England Patriots       nwe
# 47         Las Vegas Raiders       rai      Los Angeles Chargers       sdg
#
#     week  win_perc_dif  first_downs_dif  fumbles_dif  interceptions_dif  \
# 0      2      0.000000         4.000000    -2.000000           0.000000
# 1      2      1.000000        -4.000000    -1.000000          -1.000000
# 2      2      0.000000         5.000000    -1.000000           0.000000
# 3      2      0.000000        10.000000     0.000000           1.000000
# 4      2      0.000000        -3.000000     0.000000           0.000000
# 5      2      0.000000         8.000000     3.000000          -1.000000
# 6      2     -1.000000         6.000000     4.000000          -1.000000
# 7      2      1.000000         4.000000     0.000000          -3.000000
# 8      2      1.000000        -5.000000    -1.000000           0.000000
# 9      2      1.000000        -2.000000    -1.000000          -1.000000
# 10     2     -1.000000        -5.000000    -1.000000          -2.000000
# 11     2     -1.000000         2.000000     0.000000          -1.000000
# 12     2     -1.000000        -1.000000     1.000000           1.000000
# 13     2     -1.000000         3.000000    -1.000000           0.000000
# 14     2      1.000000         1.000000    -4.000000           0.000000
# 15     2      0.000000        17.000000    -1.000000          -1.000000
# 16     3      0.500000         3.000000    -0.500000           0.000000
# 17     3      0.000000        -3.000000    -1.500000           0.000000
# 18     3      0.000000        -1.500000    -1.500000           0.000000
# 19     3      0.000000         0.500000    -0.500000           1.000000
# 21     3      0.000000        -1.000000     0.500000           1.500000
# 22     3      0.000000        -6.500000    -2.500000           1.000000
# 23     3      0.000000         4.000000     0.000000           1.000000
# 24     3      1.000000         5.500000     0.500000          -1.000000
# 25     3      0.500000         0.500000     1.500000           0.000000
# 26     3     -0.500000        -9.500000     0.000000           0.500000
# 27     3     -1.000000        -6.000000     0.000000           2.500000
# 28     3      0.000000         3.000000     1.000000           0.500000
# 29     3      0.500000        -5.500000    -1.000000           0.000000
# 30     3     -0.500000        -2.500000    -1.500000           1.000000
# 31     3      0.000000        -6.500000     0.500000          -1.000000
# 32     4     -0.666667         2.000000     1.333333           1.000000
# 33     4     -0.333333        -6.333333    -0.333333           0.000000
# 34     4      0.000000        -1.000000     0.666667           0.000000
# 35     4      0.000000         7.333333     0.333333           0.333333
# 36     4      0.666667         9.666667     1.000000          -1.333333
# 37     4     -0.666667         4.666667     1.333333          -0.666667
# 38     4      0.333333        -0.666667     0.333333           0.666667
# 39     4     -0.333333         4.333333    -1.000000           0.000000
# 40     4      0.333333        -3.000000     0.000000          -0.333333
# 41     4     -0.333333         8.666667    -0.333333           0.000000
# 42     4     -0.333333        -4.333333    -1.666667          -0.333333
# 43     4      0.000000         1.666667     0.000000           1.000000
# 44     4     -0.333333        -2.000000     0.333333           0.333333
# 45     4     -0.333333        -1.000000     1.333333           1.000000
# 46     4      0.333333         5.000000     0.333333          -0.333333
# 47     4      0.333333         1.333333     0.666667          -0.333333
#
#     net_pass_yards_dif  ...  rush_yards_dif  time_of_possession_dif  \
# 0           121.000000  ...      -66.000000               55.000000
# 1            29.000000  ...       15.000000              -23.000000
# 2          -119.000000  ...       60.000000              196.000000
# 3           232.000000  ...        7.000000              445.000000
# 4            50.000000  ...      -42.000000             -270.000000
# 5            61.000000  ...       80.000000              483.000000
# 6            69.000000  ...       43.000000              600.000000
# 7           -64.000000  ...       89.000000              612.000000
# 8            89.000000  ...      -39.000000             -661.000000
# 9           -15.000000  ...        7.000000              471.000000
# 10         -243.000000  ...       72.000000              205.000000
# 11           56.000000  ...      -69.000000              108.000000
# 12          -79.000000  ...      -54.000000              146.000000
# 13           57.000000  ...      -30.000000              -96.000000
# 14          107.000000  ...     -116.000000               33.000000
# 15          128.000000  ...       73.000000              484.000000
# 16           27.500000  ...      -21.000000              296.500000
# 17         -116.000000  ...      -26.000000              128.500000
# 18           14.000000  ...      -23.500000             -285.000000
# 19          -36.500000  ...       52.000000              334.500000
# 21          -26.500000  ...      -22.000000              176.500000
# 22          -98.000000  ...       -3.500000             -255.500000
# 23          -10.000000  ...       25.000000              306.000000
# 24          109.000000  ...       44.000000              574.500000
# 25          -51.500000  ...      108.000000              245.000000
# 26         -226.000000  ...        5.500000             -409.500000
# 27          -83.000000  ...      -32.000000             -396.000000
# 28           28.000000  ...      -20.500000              -36.000000
# 29           -8.500000  ...      -13.500000             -491.000000
# 30          -43.500000  ...      -54.500000              -78.500000
# 31          -87.000000  ...       33.000000             -221.000000
# 32           22.333333  ...       -1.333333             -299.333333
# 33          -41.333333  ...      -32.666667             -262.000000
# 34            3.000000  ...       14.333333             -280.666667
# 35           59.000000  ...      -22.333333              163.000000
# 36           53.333333  ...       79.333333              365.666667
# 37          129.000000  ...      -12.666667               -8.333333
# 38          -61.666667  ...       46.666667               54.000000
# 39           39.666667  ...       10.333333              143.000000
# 40            7.333333  ...      -33.666667              145.333333
# 41          156.666667  ...        4.666667              111.666667
# 42           37.666667  ...        2.666667             -405.333333
# 43           18.000000  ...       26.333333              294.333333
# 44           33.333333  ...      -26.666667              -24.666667
# 45          -20.666667  ...       58.333333             -282.333333
# 46          123.666667  ...      -35.333333             -198.333333
# 47           72.333333  ...        4.000000              256.000000
#
#     times_sacked_dif  total_yards_dif  turnovers_dif  \
# 0           1.000000        55.000000       0.000000
# 1           2.000000        44.000000      -2.000000
# 2          -1.000000       -59.000000      -1.000000
# 3           1.000000       239.000000       1.000000
# 4           0.000000         8.000000       2.000000
# 5          -5.000000       141.000000       1.000000
# 6           1.000000       112.000000       0.000000
# 7           1.000000        25.000000      -2.000000
# 8          -2.000000        50.000000      -1.000000
# 9          -1.000000        -8.000000      -2.000000
# 10          3.000000      -171.000000      -4.000000
# 11          1.000000       -13.000000       0.000000
# 12          3.000000      -133.000000       2.000000
# 13         -1.000000        27.000000      -1.000000
# 14         -1.000000        -9.000000      -2.000000
# 15          1.000000       201.000000      -2.000000
# 16          0.500000         6.500000       0.000000
# 17          1.000000      -142.000000      -0.500000
# 18         -1.000000        -9.500000      -0.500000
# 19          3.000000        15.500000       1.500000
# 21         -1.000000       -48.500000       1.000000
# 22          0.000000      -101.500000       0.000000
# 23          1.000000        15.000000       1.000000
# 24          1.500000       153.000000      -1.000000
# 25          0.000000        56.500000       0.500000
# 26          1.500000      -220.500000       1.500000
# 27          2.500000      -115.000000       2.000000
# 28          0.500000         7.500000       1.500000
# 29          1.000000       -22.000000       0.000000
# 30          2.000000       -98.000000       0.500000
# 31          0.000000       -54.000000      -1.000000
# 32         -1.666667        21.000000       1.333333
# 33          0.666667       -74.000000      -0.333333
# 34         -1.333333        17.333333       0.333333
# 35         -0.333333        36.666667       1.333333
# 36         -1.666667       132.666667       0.000000
# 37          0.333333       116.333333       0.000000
# 38          1.333333       -15.000000       1.000000
# 39         -0.666667        50.000000      -0.333333
# 40         -0.333333       -26.333333      -0.333333
# 41         -3.000000       161.333333       0.000000
# 42          1.000000        40.333333      -1.000000
# 43          0.666667        44.333333       0.666667
# 44          0.666667         6.666667       0.000000
# 45          0.333333        37.666667       1.000000
# 46          0.000000        88.333333       0.000000
# 47          1.000000        76.333333      -0.666667
#
#     yards_from_penalties_dif  yards_lost_from_sacks_dif  fourth_down_perc_dif  \
# 0                  -9.000000                  11.000000             -0.666667
# 1                 -20.000000                  16.000000              0.666667
# 2                  -2.000000                  -9.000000              1.000000
# 3                  30.000000                  15.000000              0.000000
# 4                 -10.000000                   5.000000              0.000000
# 5                  54.000000                 -38.000000             -0.500000
# 6                  53.000000                  -1.000000              0.333333
# 7                 -31.000000                  -4.000000              0.000000
# 8                  20.000000                 -19.000000              1.000000
# 9                  20.000000                 -15.000000             -0.750000
# 10                 -7.000000                  28.000000              0.333333
# 11                 57.000000                  17.000000              1.000000
# 12                  4.000000                  43.000000              0.333333
# 13                -39.000000                   9.000000              0.000000
# 14                -35.000000                  -5.000000             -0.500000
# 15                  4.000000                   9.000000             -0.266667
# 16                -20.500000                   5.500000              0.000000
# 17                  6.500000                  15.000000             -0.750000
# 18                  1.500000                  -3.000000              0.500000
# 19                 -1.500000                  29.000000              0.500000
# 21                  9.500000                   0.500000             -0.047619
# 22                  6.500000                  -4.500000              0.500000
# 23                 55.500000                   7.500000              1.000000
# 24                -26.500000                  10.500000              0.000000
# 25                  1.500000                  -3.500000              0.380952
# 26                  4.500000                   9.500000             -0.500000
# 27                -22.500000                  21.000000             -0.600000
# 28                 69.000000                   0.000000              0.000000
# 29                 10.500000                   4.000000             -1.000000
# 30                -24.000000                  17.500000             -0.333333
# 31                  7.500000                  -6.000000              0.000000
# 32                 10.333333                 -12.666667              0.500000
# 33                  5.000000                   0.666667             -0.400000
# 34                 -0.333333                 -11.000000              0.514286
# 35                -31.333333                  -5.666667              0.000000
# 36                -23.666667                  -8.666667              0.114286
# 37                  5.333333                   1.666667             -0.166667
# 38                  6.000000                  12.000000             -0.428571
# 39                -24.000000                  -0.333333             -0.041667
# 40                 -5.666667                  -4.000000             -0.333333
# 41                  1.333333                 -23.000000              0.285714
# 42                -12.333333                   5.666667             -1.000000
# 43                 34.000000                   3.000000              0.500000
# 44                -10.000000                  -5.333333             -0.500000
# 45                 -2.333333                  -1.333333             -0.250000
# 46                 20.666667                  -7.000000             -0.166667
# 47                -12.333333                  10.000000             -0.666667
#
#     third_down_perc_dif  result
# 0              0.200000     0.0
# 1             -0.240260     0.0
# 2              0.214286     0.0
# 3              0.133333     1.0
# 4             -0.128205     1.0
# 5              0.379808     1.0
# 6              0.080808     1.0
# 7              0.193939     1.0
# 8              0.160839     1.0
# 9              0.285714     0.0
# 10            -0.240260     0.0
# 11            -0.163462     0.0
# 12            -0.087302     1.0
# 13            -0.207430     1.0
# 14             0.442308     0.0
# 15             0.166667     0.0
# 16            -0.157635     1.0
# 17             0.048077     0.0
# 18            -0.179523     0.0
# 19            -0.041667     1.0
# 21            -0.106322     1.0
# 22            -0.166667     1.0
# 23             0.086587     1.0
# 24             0.136364     1.0
# 25             0.057971     1.0
# 26            -0.014778     0.0
# 27             0.000000     0.0
# 28            -0.058696     0.0
# 29             0.073260     0.0
# 30            -0.075515     1.0
# 31            -0.115556     0.0
# 32            -0.060606     0.0
# 33            -0.044466     0.0
# 34            -0.068627     1.0
# 35             0.146319     1.0
# 36             0.091667     0.0
# 37             0.065015     1.0
# 38            -0.000758     1.0
# 39            -0.021868     1.0
# 40            -0.113462     0.0
# 41            -0.000795     0.0
# 42            -0.091278     1.0
# 43            -0.188018     1.0
# 44             0.051938     0.0
# 45            -0.048321     1.0
# 46            -0.030142     1.0
# 47            -0.082503     0.0
#
# [47 rows x 28 columns]

# %%
train_df = comp_games_df
test_df = pred_games_df

X_train = train_df.drop(columns = ['away_name', 'away_abbr', 'home_name', 'home_abbr', 'week','result'])
y_train = train_df[['result']] 
X_test = test_df.drop(columns = ['away_name', 'away_abbr', 'home_name', 'home_abbr', 'week','result'])
y_test = test_df[['result']]

# %%
from sklearn.linear_model import LogisticRegression

clf = LogisticRegression(penalty='l1', dual=False, tol=0.001, C=1.0, fit_intercept=True, 
                   intercept_scaling=1, class_weight='balanced', random_state=None, 
                   solver='liblinear', max_iter=1000, multi_class='ovr', verbose=0)

clf.fit(X_train, np.ravel(y_train.values))
y_pred = clf.predict_proba(X_test)
y_pred = y_pred[:,1]

display(y_pred,test_df)
# Out:
# The Jacksonville Jaguars have a probability of 0.17 of beating the Cincinnati Bengals.
# The Houston Texans have a probability of 0.18 of beating the Buffalo Bills.
# The Washington Football Team have a probability of 0.42 of beating the Atlanta Falcons.
# The Kansas City Chiefs have a probability of 0.82 of beating the Philadelphia Eagles.
# The Tennessee Titans have a probability of 0.41 of beating the New York Jets.
# The New York Giants have a probability of 0.7 of beating the New Orleans Saints.
# The Cleveland Browns have a probability of 0.99 of beating the Minnesota Vikings.
# The Indianapolis Colts have a probability of 0.97 of beating the Miami Dolphins.
# The Carolina Panthers have a probability of 0.18 of beating the Dallas Cowboys.
# The Detroit Lions have a probability of 0.32 of beating the Chicago Bears.
# The Seattle Seahawks have a probability of 0.83 of beating the San Francisco 49ers.
# The Arizona Cardinals have a probability of 0.99 of beating the Los Angeles Rams.
# The Pittsburgh Steelers have a probability of 0.31 of beating the Green Bay Packers.
# The Baltimore Ravens have a probability of 0.96 of beating the Denver Broncos.
# The Tampa Bay Buccaneers have a probability of 0.43 of beating the New England Patriots.
# The Las Vegas Raiders have a probability of 0.5 of beating the Los Angeles Chargers.

# %%
from sklearn.metrics import accuracy_score

accuracy_score(y_test,np.round(y_pred))
# Out:
# 0.8125

# %%
x = pd.DataFrame(index=y_test.index)

x['Predictions'] = y_pred
x['Actual'] = y_test

x
# Out:
#     Predictions  Actual
# 32     0.165681     0.0
# 33     0.183551     0.0
# 34     0.417285     1.0
# 35     0.818487     1.0
# 36     0.410215     0.0
# 37     0.701734     1.0
# 38     0.991710     1.0
# 39     0.966828     1.0
# 40     0.178463     0.0
# 41     0.321419     0.0
# 42     0.825786     1.0
# 43     0.987685     1.0
# 44     0.311714     0.0
# 45     0.958258     1.0
# 46     0.433556     1.0
# 47     0.500968     0.0

# %%
import xgboost as xgb

dtest = xgb.DMatrix(X_test, y_test, feature_names=X_test.columns)
dtrain = xgb.DMatrix(X_train, y_train,feature_names=X_train.columns)

param = {'verbosity':1, 
         'objective':'binary:hinge',
         'feature_selector': 'shuffle',
         'booster':'gblinear',
         'eval_metric' :'error',
         'learning_rate': 0.05}

evallist = [(dtrain, 'train'), (dtest, 'test')]

# %%
num_round = 300
bst = xgb.train(param, dtrain, num_round, evallist)
# Out:
# [0]	train-error:0.49138	test-error:0.35714
# [1]	train-error:0.46552	test-error:0.35714
# [2]	train-error:0.42241	test-error:0.35714
# [3]	train-error:0.39655	test-error:0.28571
# [4]	train-error:0.35345	test-error:0.21429
# [5]	train-error:0.35345	test-error:0.21429
# [6]	train-error:0.32759	test-error:0.21429
# [7]	train-error:0.31897	test-error:0.21429
# [8]	train-error:0.31897	test-error:0.21429
# [9]	train-error:0.31034	test-error:0.21429
# [10]	train-error:0.27586	test-error:0.21429
# [11]	train-error:0.27586	test-error:0.21429
# [12]	train-error:0.25862	test-error:0.21429
# [13]	train-error:0.26724	test-error:0.21429
# [14]	train-error:0.26724	test-error:0.21429
# [15]	train-error:0.26724	test-error:0.21429
# [16]	train-error:0.26724	test-error:0.21429
# [17]	train-error:0.25000	test-error:0.21429
# [18]	train-error:0.24138	test-error:0.21429
# [19]	train-error:0.25000	test-error:0.21429
# [20]	train-error:0.25000	test-error:0.21429
# [21]	train-error:0.24138	test-error:0.21429
# [22]	train-error:0.24138	test-error:0.21429
# [23]	train-error:0.24138	test-error:0.21429
# [24]	train-error:0.24138	test-error:0.21429
# [25]	train-error:0.24138	test-error:0.21429
# [26]	train-error:0.24138	test-error:0.21429
# [27]	train-error:0.24138	test-error:0.21429
# [28]	train-error:0.24138	test-error:0.21429
# [29]	train-error:0.24138	test-error:0.21429
# [30]	train-error:0.24138	test-error:0.21429
# [31]	train-error:0.24138	test-error:0.21429
# [32]	train-error:0.24138	test-error:0.21429
# [33]	train-error:0.23276	test-error:0.21429
# [34]	train-error:0.23276	test-error:0.21429
# [35]	train-error:0.23276	test-error:0.21429
# [36]	train-error:0.23276	test-error:0.21429
# [37]	train-error:0.23276	test-error:0.21429
# [38]	train-error:0.23276	test-error:0.21429
# [39]	train-error:0.23276	test-error:0.21429
# [40]	train-error:0.23276	test-error:0.21429
# [41]	train-error:0.23276	test-error:0.21429
# [42]	train-error:0.23276	test-error:0.21429
# [43]	train-error:0.23276	test-error:0.21429
# [44]	train-error:0.23276	test-error:0.21429
# [45]	train-error:0.23276	test-error:0.21429
# [46]	train-error:0.23276	test-error:0.21429
# [47]	train-error:0.24138	test-error:0.21429
# [48]	train-error:0.24138	test-error:0.21429
# [49]	train-error:0.24138	test-error:0.21429
# [50]	train-error:0.24138	test-error:0.21429
# [51]	train-error:0.24138	test-error:0.21429
# [52]	train-error:0.24138	test-error:0.21429
# [53]	train-error:0.24138	test-error:0.21429
# [54]	train-error:0.24138	test-error:0.21429
# [55]	train-error:0.24138	test-error:0.21429
# [56]	train-error:0.24138	test-error:0.21429
# [57]	train-error:0.24138	test-error:0.21429
# [58]	train-error:0.24138	test-error:0.21429
# [59]	train-error:0.24138	test-error:0.21429
# [60]	train-error:0.24138	test-error:0.21429
# [61]	train-error:0.25000	test-error:0.28571
# [62]	train-error:0.24138	test-error:0.21429
# [63]	train-error:0.25000	test-error:0.28571
# [64]	train-error:0.24138	test-error:0.21429
# [65]	train-error:0.25000	test-error:0.28571
# [66]	train-error:0.25000	test-error:0.28571
# [67]	train-error:0.25000	test-error:0.28571
# [68]	train-error:0.25000	test-error:0.28571
# [69]	train-error:0.25000	test-error:0.28571
# [70]	train-error:0.25000	test-error:0.28571
# [71]	train-error:0.25000	test-error:0.28571
# [72]	train-error:0.25000	test-error:0.28571
# [73]	train-error:0.25000	test-error:0.28571
# [74]	train-error:0.25000	test-error:0.28571
# [75]	train-error:0.25000	test-error:0.28571
# [76]	train-error:0.25000	test-error:0.28571
# [77]	train-error:0.25000	test-error:0.28571
# [78]	train-error:0.25000	test-error:0.28571
# [79]	train-error:0.25000	test-error:0.28571
# [80]	train-error:0.25000	test-error:0.28571
# [81]	train-error:0.25000	test-error:0.28571
# [82]	train-error:0.25000	test-error:0.28571
# [83]	train-error:0.25000	test-error:0.28571
# [84]	train-error:0.25000	test-error:0.28571
# [85]	train-error:0.25000	test-error:0.28571
# [86]	train-error:0.25000	test-error:0.28571
# [87]	train-error:0.25000	test-error:0.28571
# [88]	train-error:0.25000	test-error:0.28571
# [89]	train-error:0.25000	test-error:0.28571
# [90]	train-error:0.25000	test-error:0.28571
# [91]	train-error:0.25000	test-error:0.28571
# [92]	train-error:0.25000	test-error:0.28571
# [93]	train-error:0.25000	test-error:0.28571
# [94]	train-error:0.24138	test-error:0.28571
# [95]	train-error:0.25000	test-error:0.28571
# [96]	train-error:0.24138	test-error:0.28571
# [97]	train-error:0.24138	test-error:0.28571
# [98]	train-error:0.24138	test-error:0.28571
# [99]	train-error:0.24138	test-error:0.28571
# [100]	train-error:0.24138	test-error:0.28571
# [101]	train-error:0.24138	test-error:0.28571
# [102]	train-error:0.24138	test-error:0.28571
# [103]	train-error:0.24138	test-error:0.28571
# [104]	train-error:0.24138	test-error:0.28571
# [105]	train-error:0.24138	test-error:0.28571
# [106]	train-error:0.24138	test-error:0.28571
# [107]	train-error:0.24138	test-error:0.28571
# [108]	train-error:0.24138	test-error:0.28571
# [109]	train-error:0.24138	test-error:0.28571
# [110]	train-error:0.24138	test-error:0.28571
# [111]	train-error:0.24138	test-error:0.28571
# [112]	train-error:0.24138	test-error:0.28571
# [113]	train-error:0.24138	test-error:0.28571
# [114]	train-error:0.24138	test-error:0.28571
# [115]	train-error:0.24138	test-error:0.28571
# [116]	train-error:0.24138	test-error:0.28571
# [117]	train-error:0.23276	test-error:0.28571
# [118]	train-error:0.23276	test-error:0.28571
# [119]	train-error:0.23276	test-error:0.28571
# [120]	train-error:0.23276	test-error:0.28571
# [121]	train-error:0.23276	test-error:0.28571
# [122]	train-error:0.23276	test-error:0.28571
# [123]	train-error:0.23276	test-error:0.28571
# [124]	train-error:0.23276	test-error:0.28571
# [125]	train-error:0.23276	test-error:0.28571
# [126]	train-error:0.23276	test-error:0.28571
# [127]	train-error:0.23276	test-error:0.28571
# [128]	train-error:0.23276	test-error:0.28571
# [129]	train-error:0.23276	test-error:0.28571
# [130]	train-error:0.23276	test-error:0.28571
# [131]	train-error:0.23276	test-error:0.28571
# [132]	train-error:0.23276	test-error:0.28571
# [133]	train-error:0.23276	test-error:0.28571
# [134]	train-error:0.23276	test-error:0.28571
# [135]	train-error:0.24138	test-error:0.28571
# [136]	train-error:0.23276	test-error:0.28571
# [137]	train-error:0.24138	test-error:0.28571
# [138]	train-error:0.24138	test-error:0.28571
# [139]	train-error:0.23276	test-error:0.28571
# [140]	train-error:0.25000	test-error:0.28571
# [141]	train-error:0.24138	test-error:0.28571
# [142]	train-error:0.25000	test-error:0.28571
# [143]	train-error:0.24138	test-error:0.28571
# [144]	train-error:0.25000	test-error:0.28571
# [145]	train-error:0.25000	test-error:0.28571
# [146]	train-error:0.25000	test-error:0.28571
# [147]	train-error:0.25000	test-error:0.28571
# [148]	train-error:0.25000	test-error:0.28571
# [149]	train-error:0.25000	test-error:0.28571
# [150]	train-error:0.25000	test-error:0.28571
# [151]	train-error:0.25000	test-error:0.28571
# [152]	train-error:0.25000	test-error:0.28571
# [153]	train-error:0.25000	test-error:0.28571
# [154]	train-error:0.25000	test-error:0.28571
# [155]	train-error:0.24138	test-error:0.28571
# [156]	train-error:0.25000	test-error:0.28571
# [157]	train-error:0.24138	test-error:0.28571
# [158]	train-error:0.24138	test-error:0.28571
# [159]	train-error:0.24138	test-error:0.28571
# [160]	train-error:0.24138	test-error:0.28571
# [161]	train-error:0.24138	test-error:0.28571
# [162]	train-error:0.23276	test-error:0.28571
# [163]	train-error:0.24138	test-error:0.28571
# [164]	train-error:0.23276	test-error:0.28571
# [165]	train-error:0.24138	test-error:0.28571
# [166]	train-error:0.24138	test-error:0.28571
# [167]	train-error:0.23276	test-error:0.28571
# [168]	train-error:0.24138	test-error:0.28571
# [169]	train-error:0.24138	test-error:0.28571
# [170]	train-error:0.24138	test-error:0.28571
# [171]	train-error:0.24138	test-error:0.28571
# [172]	train-error:0.25000	test-error:0.28571
# [173]	train-error:0.24138	test-error:0.28571
# [174]	train-error:0.25000	test-error:0.28571
# [175]	train-error:0.24138	test-error:0.28571
# [176]	train-error:0.24138	test-error:0.28571
# [177]	train-error:0.24138	test-error:0.28571
# [178]	train-error:0.24138	test-error:0.28571
# [179]	train-error:0.24138	test-error:0.28571
# [180]	train-error:0.24138	test-error:0.28571
# [181]	train-error:0.24138	test-error:0.28571
# [182]	train-error:0.24138	test-error:0.28571
# [183]	train-error:0.24138	test-error:0.28571
# [184]	train-error:0.24138	test-error:0.28571
# [185]	train-error:0.24138	test-error:0.28571
# [186]	train-error:0.24138	test-error:0.28571
# [187]	train-error:0.24138	test-error:0.28571
# [188]	train-error:0.24138	test-error:0.28571
# [189]	train-error:0.24138	test-error:0.28571
# [190]	train-error:0.24138	test-error:0.28571
# [191]	train-error:0.24138	test-error:0.28571
# [192]	train-error:0.24138	test-error:0.28571
# [193]	train-error:0.24138	test-error:0.28571
# [194]	train-error:0.24138	test-error:0.28571
# [195]	train-error:0.24138	test-error:0.28571
# [196]	train-error:0.24138	test-error:0.28571
# [197]	train-error:0.24138	test-error:0.28571
# [198]	train-error:0.24138	test-error:0.28571
# [199]	train-error:0.24138	test-error:0.28571
# [200]	train-error:0.24138	test-error:0.28571
# [201]	train-error:0.24138	test-error:0.28571
# [202]	train-error:0.24138	test-error:0.28571
# [203]	train-error:0.24138	test-error:0.28571
# [204]	train-error:0.24138	test-error:0.28571
# [205]	train-error:0.24138	test-error:0.28571
# [206]	train-error:0.24138	test-error:0.28571
# [207]	train-error:0.24138	test-error:0.28571
# [208]	train-error:0.24138	test-error:0.28571
# [209]	train-error:0.24138	test-error:0.28571
# [210]	train-error:0.24138	test-error:0.28571
# [211]	train-error:0.24138	test-error:0.28571
# [212]	train-error:0.24138	test-error:0.28571
# [213]	train-error:0.24138	test-error:0.28571
# [214]	train-error:0.24138	test-error:0.28571
# [215]	train-error:0.24138	test-error:0.28571
# [216]	train-error:0.24138	test-error:0.28571
# [217]	train-error:0.24138	test-error:0.28571
# [218]	train-error:0.24138	test-error:0.28571
# [219]	train-error:0.24138	test-error:0.28571
# [220]	train-error:0.23276	test-error:0.28571
# [221]	train-error:0.23276	test-error:0.28571
# [222]	train-error:0.24138	test-error:0.28571
# [223]	train-error:0.24138	test-error:0.28571
# [224]	train-error:0.24138	test-error:0.28571
# [225]	train-error:0.23276	test-error:0.28571
# [226]	train-error:0.23276	test-error:0.28571
# [227]	train-error:0.24138	test-error:0.28571
# [228]	train-error:0.23276	test-error:0.28571
# [229]	train-error:0.24138	test-error:0.28571
# [230]	train-error:0.23276	test-error:0.28571
# [231]	train-error:0.24138	test-error:0.28571
# [232]	train-error:0.24138	test-error:0.28571
# [233]	train-error:0.23276	test-error:0.28571
# [234]	train-error:0.23276	test-error:0.28571
# [235]	train-error:0.24138	test-error:0.28571
# [236]	train-error:0.23276	test-error:0.28571
# [237]	train-error:0.24138	test-error:0.28571
# [238]	train-error:0.24138	test-error:0.28571
# [239]	train-error:0.25000	test-error:0.28571
# [240]	train-error:0.24138	test-error:0.28571
# [241]	train-error:0.24138	test-error:0.28571
# [242]	train-error:0.25000	test-error:0.28571
# [243]	train-error:0.24138	test-error:0.28571
# [244]	train-error:0.24138	test-error:0.28571
# [245]	train-error:0.24138	test-error:0.28571
# [246]	train-error:0.24138	test-error:0.28571
# [247]	train-error:0.24138	test-error:0.28571
# [248]	train-error:0.25000	test-error:0.28571
# [249]	train-error:0.24138	test-error:0.28571
# [250]	train-error:0.24138	test-error:0.28571
# [251]	train-error:0.24138	test-error:0.28571
# [252]	train-error:0.24138	test-error:0.28571
# [253]	train-error:0.24138	test-error:0.28571
# [254]	train-error:0.24138	test-error:0.28571
# [255]	train-error:0.24138	test-error:0.28571
# [256]	train-error:0.24138	test-error:0.28571
# [257]	train-error:0.24138	test-error:0.28571
# [258]	train-error:0.24138	test-error:0.28571
# [259]	train-error:0.24138	test-error:0.28571
# [260]	train-error:0.24138	test-error:0.28571
# [261]	train-error:0.24138	test-error:0.28571
# [262]	train-error:0.25000	test-error:0.28571
# [263]	train-error:0.24138	test-error:0.28571
# [264]	train-error:0.24138	test-error:0.28571
# [265]	train-error:0.24138	test-error:0.28571
# [266]	train-error:0.24138	test-error:0.28571
# [267]	train-error:0.24138	test-error:0.28571
# [268]	train-error:0.24138	test-error:0.28571
# [269]	train-error:0.24138	test-error:0.28571
# [270]	train-error:0.24138	test-error:0.28571
# [271]	train-error:0.24138	test-error:0.28571
# [272]	train-error:0.24138	test-error:0.28571
# [273]	train-error:0.24138	test-error:0.28571
# [274]	train-error:0.24138	test-error:0.28571
# [275]	train-error:0.24138	test-error:0.28571
# [276]	train-error:0.24138	test-error:0.28571
# [277]	train-error:0.24138	test-error:0.28571
# [278]	train-error:0.24138	test-error:0.28571
# [279]	train-error:0.24138	test-error:0.28571
# [280]	train-error:0.24138	test-error:0.28571
# [281]	train-error:0.24138	test-error:0.28571
# [282]	train-error:0.24138	test-error:0.28571
# [283]	train-error:0.24138	test-error:0.28571
# [284]	train-error:0.24138	test-error:0.28571
# [285]	train-error:0.24138	test-error:0.28571
# [286]	train-error:0.23276	test-error:0.21429
# [287]	train-error:0.24138	test-error:0.28571
# [288]	train-error:0.24138	test-error:0.28571
# [289]	train-error:0.23276	test-error:0.21429
# [290]	train-error:0.24138	test-error:0.28571
# [291]	train-error:0.23276	test-error:0.21429
# [292]	train-error:0.23276	test-error:0.21429
# [293]	train-error:0.24138	test-error:0.28571
# [294]	train-error:0.23276	test-error:0.21429
# [295]	train-error:0.23276	test-error:0.21429
# [296]	train-error:0.24138	test-error:0.28571
# [297]	train-error:0.23276	test-error:0.21429
# [298]	train-error:0.24138	test-error:0.28571
# [299]	train-error:0.23276	test-error:0.21429

# %%
X_test = pred_games_df.drop(columns = ['away_name', 'away_abbr', 'home_name', 'home_abbr', 'week','result'])
y_pred = clf.predict_proba(X_test)
y_pred = y_pred[:,1]

display(y_pred,pred_games_df)
# Out:
# The Green Bay Packers have a probability of 0.92 of beating the San Francisco 49ers.
# The Seattle Seahawks have a probability of 0.5 of beating the Buffalo Bills.
# The Denver Broncos have a probability of 0.34 of beating the Atlanta Falcons.
# The New York Giants have a probability of 0.7 of beating the Washington Football Team.
# The Chicago Bears have a probability of 0.54 of beating the Tennessee Titans.
# The Detroit Lions have a probability of 0.47 of beating the Minnesota Vikings.
# The Carolina Panthers have a probability of 0.08 of beating the Kansas City Chiefs.
# The Houston Texans have a probability of 0.86 of beating the Jacksonville Jaguars.
# The Baltimore Ravens have a probability of 0.79 of beating the Indianapolis Colts.
# The Las Vegas Raiders have a probability of 0.83 of beating the Los Angeles Chargers.
# The Pittsburgh Steelers have a probability of 0.99 of beating the Dallas Cowboys.
# The Miami Dolphins have a probability of 0.3 of beating the Arizona Cardinals.
# The New Orleans Saints have a probability of 0.61 of beating the Tampa Bay Buccaneers.
# The New England Patriots have a probability of 0.84 of beating the New York Jets.
