# %%
# Install libraries
import pandas as pd
from pathlib import Path

# %%
# Import team_stats csv
nfl_stats_df = pd.read_csv(Path("nfl_team_stats_2002-2020.csv"))

# %%
nfl_stats_df.head()
# Out:
#      date      away     home  first_downs_away  first_downs_home  \
# 0  9/5/02     49ers   Giants                13                21
# 1  9/8/02      Jets    Bills                18                26
# 2  9/8/02   Vikings    Bears                19                20
# 3  9/8/02  Chargers  Bengals                27                13
# 4  9/8/02    Chiefs   Browns                24                24
#
#   third_downs_away third_downs_home fourth_downs_away fourth_downs_home  \
# 0           12-Apr           16-Sep               0-0               0-1
# 1            8-Feb           17-Jul               0-0             2-Feb
# 2           13-May           13-Jul               0-0               0-0
# 3           10-Jun           11-Apr               0-0               0-0
# 4           11-May           11-Apr               0-0               0-0
#
#    passing_yards_away  ...  redzone_away  redzone_home  drives_away  \
# 0                 166  ...           0-8           0-6           13
# ...
